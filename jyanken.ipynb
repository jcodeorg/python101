# %% [markdown]
# # じゃんけんゲーム（基本版・穴埋め）
# このノートブックでは、Python を使ってじゃんけんゲームの基本版を作成します。
#
# ## 今日やること
# - リストを使って手を管理する
# - random を使ってコンピュータの手を決める
# - 条件分岐で勝敗判定を行う
# - 入力と出力を使ってゲームを動かす
#
# ---
# ## ① ライブラリの読み込み
# まずは random を読み込みます。

# %%
import ___  # random を読み込みます

# %% [markdown]
# ## ② じゃんけんの手をリストで作る
# リスト hands に「グー」「チョキ」「パー」を入れます。
# 文字列はダブルクォーテーションで囲んで入力することに注意してください。

# %%
hands = [___, ___, ___]  # グー・チョキ・パーを入れる

# %% [markdown]
# ## ③ プレイヤーの入力を受け取る
# input() を使って、数字（0, 1, 2）を入力してもらいます。

# %%
print("0: グー, 1: チョキ, 2: パー")
player = int(_____("あなたの手を数字で入力してください: "))  # 入力を受け取る

# %% [markdown]
# ## ④ コンピュータの手をランダムに決める
# random.randint(0, 2) を使います。

# %%
computer = ___.randint(0, 2)  # コンピュータの手を決める

# %% [markdown]
# ## ⑤ 手を表示する
# リスト hands を使って、グー・チョキ・パーのいずれかを表示します。

# %%
print("あなた：", hands[_____])
print("コンピュータ：", hands[______])

# %% [markdown]
# ## ⑥ 勝敗判定（条件分岐）
# ここがじゃんけんのメイン部分です。
# まずは「あいこ」の条件を書きます。

# %%
if player == computer:  # あなたとコンピュータが同じ手の場合
    print("あいこです")
elif player == 0 and computer == 1: # あなたがグーでコンピュータがチョキの場合
    print("あなたの勝ち！")
elif player == _ and computer == _: # あなたがチョキでコンピュータがパーの場合
    print("あなたの勝ち！")
elif ___________ ___ _____________: # あなたがパーでコンピュータがグーの場合
    print("あなたの勝ち！")
else:
    print("あなたの___…")  # それ以外の場合は？

# %% [markdown]
# ---
# ## ここまでで基本版が完成！
# 次回はこのゲームを自分だけの作品に改造していきます。
# - 勝ち数・負け数を記録する
# - 3回勝ったらゲーム終了にする
# - 絵文字でじゃんけんを表示する
# - コンピュータが強い戦略を持つようにする
# - 手を増やす（遊び要素）
#
# 楽しみにしていてください。
