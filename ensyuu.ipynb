# %%
import random

a = random.randint(1,10)
b = random.randint(1,10)
print("a + b = ", a + b)
print("a - b = ", a - b)

n = int(input("a はいくつ？"))
if a == n:
    print("正解")
else:
    print("不正解。正解は ", a)
